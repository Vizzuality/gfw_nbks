# %% [markdown]
# # Scraping External Links from Old GFW Country Pages

# %% [markdown]
# We want to scrape external links attributed to each country from the old coutry page widgets. We do this using the following endpoint:
#
# ```
# http://api.globalforestwatch.org/countries/cmr?thresh=30
# ```
#
# where the only variable we need to consider is the ISO-3 code (CMR for Cameroon is this case). Thsi returns a JSON comtainig the attribute ```external_links``` which holds a list of key:value pairs with *title* and *url* values for any links.
#
# In particular we are interested in **Forest Atlas** links, and should indicate whether a Forest Atlas link is present.
#
# The final data frame should contain a row for each ISO and have a colums for:
#
# - iso (```string```)
# - forest_atlas (```bool```)
# - external_links (```list``` of ```objects```)
#
# SCRAPED DATA FOUND HERE: https://wri-01.carto.com/tables/external_links_gfw/table

# %%
import requests
import requests_cache
from pprint import pprint
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
requests_cache.install_cache('demo_cache')

# %%
# Get all countries from endpoint

ds = '499682b1-3174-493f-ba1a-368b4636708e'  # ADMIN 2 level data
url = f"https://production-api.globalforestwatch.org/v1/query/{ds}"
sql = (f"SELECT iso, polyname FROM {ds} WHERE thresh = 0 AND polyname is 'gadm28' GROUP BY iso")

properties = {"sql": sql}
r = requests.get(url, params = properties)
print(r.url)
print(f'Status: {r.status_code}')
data = r.json().get('data')
pprint(data)
# Out:
# https://production-api.globalforestwatch.org/v1/query/499682b1-3174-493f-ba1a-368b4636708e?sql=SELECT+iso%2C+polyname+FROM+499682b1-3174-493f-ba1a-368b4636708e+WHERE+thresh+%3D+0+AND+polyname+is+%27gadm28%27+GROUP+BY+iso
# Status: 200
# [{'iso': 'BRA'},
#  {'iso': 'USA'},
#  {'iso': 'ROU'},
#  {'iso': 'RUS'},
#  {'iso': 'MEX'},
#  {'iso': 'JPN'},
#  {'iso': 'PHL'},
#  {'iso': 'AUS'},
#  {'iso': 'DZA'},
#  {'iso': 'COL'},
#  {'iso': 'THA'},
#  {'iso': 'TUR'},
#  {'iso': 'NGA'},
#  {'iso': 'VNM'},
#  {'iso': 'IND'},
#  {'iso': 'UKR'},
#  {'iso': 'HRV'},
#  {'iso': 'ARG'},
#  {'iso': 'NLD'},
#  {'iso': 'IDN'},
#  {'iso': 'NOR'},
#  {'iso': 'DEU'},
#  {'iso': 'POL'},
#  {'iso': 'GTM'},
#  {'iso': 'CHN'},
#  {'iso': 'VEN'},
#  {'iso': 'LKA'},
#  {'iso': 'EGY'},
#  {'iso': 'KEN'},
#  {'iso': 'YEM'},
#  {'iso': 'HND'},
#  {'iso': 'AFG'},
#  {'iso': 'CAN'},
#  {'iso': 'SWE'},
#  {'iso': 'PRT'},
#  {'iso': 'MNG'},
#  {'iso': 'SLV'},
#  {'iso': 'BGR'},
#  {'iso': 'MWI'},
#  {'iso': 'IRN'},
#  {'iso': 'KOR'},
#  {'iso': 'EST'},
#  {'iso': 'PRY'},
#  {'iso': 'BTN'},
#  {'iso': 'TUN'},
#  {'iso': 'URY'},
#  {'iso': 'ECU'},
#  {'iso': 'PER'},
#  {'iso': 'SVN'},
#  {'iso': 'GBR'},
#  {'iso': 'PRK'},
#  {'iso': 'TZA'},
#  {'iso': 'SLB'},
#  {'iso': 'KHM'},
#  {'iso': 'KAZ'},
#  {'iso': 'CHE'},
#  {'iso': 'CUB'},
#  {'iso': 'HUN'},
#  {'iso': 'AGO'},
#  {'iso': 'UGA'},
#  {'iso': 'SRB'},
#  {'iso': 'UZB'},
#  {'iso': 'DOM'},
#  {'iso': 'MYS'},
#  {'iso': 'LAO'},
#  {'iso': 'NIC'},
#  {'iso': 'GHA'},
#  {'iso': 'BDI'},
#  {'iso': 'MOZ'},
#  {'iso': 'BLR'},
#  {'iso': 'GUY'},
#  {'iso': 'ITA'},
#  {'iso': 'NAM'},
#  {'iso': 'DNK'},
#  {'iso': 'CZE'},
#  {'iso': 'AUT'},
#  {'iso': 'FRA'},
#  {'iso': 'IRQ'},
#  {'iso': 'BOL'},
#  {'iso': 'PNG'},
#  {'iso': 'MKD'},
#  {'iso': 'CRI'},
#  {'iso': 'SDN'},
#  {'iso': 'AZE'},
#  {'iso': 'ETH'},
#  {'iso': 'PAN'},
#  {'iso': 'SVK'},
#  {'iso': 'PRI'},
#  {'iso': 'BEN'},
#  {'iso': 'NZL'},
#  {'iso': 'SOM'},
#  {'iso': 'ZMB'},
#  {'iso': 'GEO'},
#  {'iso': 'LBR'},
#  {'iso': 'BGD'},
#  {'iso': 'MMR'},
#  {'iso': 'VUT'},
#  {'iso': 'SUR'},
#  {'iso': 'TLS'},
#  {'iso': 'ZWE'},
#  {'iso': 'TJK'},
#  {'iso': 'CMR'},
#  {'iso': 'SYR'},
#  {'iso': 'SWZ'},
#  {'iso': 'MAR'},
#  {'iso': 'TCD'},
#  {'iso': 'ESP'},
#  {'iso': 'ZAF'},
#  {'iso': 'CAF'},
#  {'iso': 'CHL'},
#  {'iso': 'ERI'},
#  {'iso': 'COG'},
#  {'iso': 'LTU'},
#  {'iso': 'OMN'},
#  {'iso': 'MLI'},
#  {'iso': 'BFA'},
#  {'iso': 'SEN'},
#  {'iso': 'SSD'},
#  {'iso': 'KGZ'},
#  {'iso': 'HTI'},
#  {'iso': 'COD'},
#  {'iso': 'ALB'},
#  {'iso': 'GAB'},
#  {'iso': 'GMB'},
#  {'iso': 'GNB'},
#  {'iso': 'JOR'},
#  {'iso': 'MDA'},
#  {'iso': 'NER'},
#  {'iso': 'GIN'},
#  {'iso': 'NCL'},
#  {'iso': 'CIV'},
#  {'iso': 'MRT'},
#  {'iso': 'BHS'},
#  {'iso': 'BRN'},
#  {'iso': 'GLP'},
#  {'iso': 'MTQ'},
#  {'iso': 'PAK'},
#  {'iso': 'GNQ'},
#  {'iso': 'LBN'},
#  {'iso': 'RWA'},
#  {'iso': 'XKO'},
#  {'iso': 'BWA'},
#  {'iso': 'IRL'},
#  {'iso': 'LVA'},
#  {'iso': 'IMN'},
#  {'iso': 'REU'},
#  {'iso': 'MDG'},
#  {'iso': 'TWN'},
#  {'iso': 'CPV'},
#  {'iso': 'FIN'},
#  {'iso': 'GUF'},
#  {'iso': 'LBY'},
#  {'iso': 'MNE'},
#  {'iso': 'TGO'},
#  {'iso': 'VIR'},
#  {'iso': 'BIH'},
#  {'iso': 'HKG'},
#  {'iso': 'MYT'},
#  {'iso': 'ALA'},
#  {'iso': 'PSE'},
#  {'iso': 'GGY'},
#  {'iso': 'TTO'},
#  {'iso': 'FJI'},
#  {'iso': 'GRC'},
#  {'iso': 'JAM'},
#  {'iso': 'KNA'},
#  {'iso': 'NPL'},
#  {'iso': 'SLE'},
#  {'iso': 'PLW'},
#  {'iso': 'BEL'},
#  {'iso': 'JEY'},
#  {'iso': 'LUX'},
#  {'iso': 'SAU'},
#  {'iso': 'ARM'},
#  {'iso': 'BMU'},
#  {'iso': 'BRB'},
#  {'iso': 'LIE'},
#  {'iso': 'DJI'},
#  {'iso': 'DMA'},
#  {'iso': 'LCA'},
#  {'iso': 'LSO'},
#  {'iso': 'MUS'},
#  {'iso': 'SMR'},
#  {'iso': 'ARE'},
#  {'iso': 'ATG'},
#  {'iso': 'MAC'},
#  {'iso': 'AND'},
#  {'iso': 'CYM'},
#  {'iso': 'GRD'},
#  {'iso': 'ISR'},
#  {'iso': 'STP'},
#  {'iso': 'BLZ'},
#  {'iso': 'KWT'},
#  {'iso': 'TCA'},
#  {'iso': 'TKM'},
#  {'iso': 'VCT'},
#  {'iso': 'CYP'},
#  {'iso': 'SGP'},
#  {'iso': 'VGB'},
#  {'iso': 'XNC'},
#  {'iso': 'BHR'},
#  {'iso': 'QAT'},
#  {'iso': 'BES'},
#  {'iso': 'COM'},
#  {'iso': 'MSR'},
#  {'iso': 'ESH'},
#  {'iso': 'SPM'},
#  {'iso': 'XAD'},
#  {'iso': 'ABW'},
#  {'iso': 'AIA'},
#  {'iso': 'ATF'},
#  {'iso': 'BLM'},
#  {'iso': 'CUW'},
#  {'iso': 'FLK'},
#  {'iso': 'FSM'},
#  {'iso': 'GIB'},
#  {'iso': 'GRL'},
#  {'iso': 'MAF'},
#  {'iso': 'MCO'},
#  {'iso': 'MDV'},
#  {'iso': 'MLT'},
#  {'iso': 'SXM'},
#  {'iso': 'SYC'},
#  {'iso': 'UMI'},
#  {'iso': 'VAT'},
#  {'iso': 'XCA'}]

# %%
# Populate list with isos

isos = []
for d in data:
    isos.append(d.get('iso'))
    
isos[0:3], len(isos)
# Out:
# (['BRA', 'USA', 'ROU'], 226)

# %%
# Function to call endpoint with an iso and append object to list .
# If country no present on api call, return None in links value

def scraper(iso, links):

    url = f"http://api.globalforestwatch.org/countries/{iso}?thresh=30"

    try:
        r = requests.get(url)
        links.append({'iso': iso, 'links': r.json().get('external_links')})
        
    except:
        links.append({'iso': iso, 'links': None})
    
    print(iso, "done!")
    
    return

# %%
# %%time
#Run through all isos from list and populate list with iso and links

links = []
for i in isos:
    scraper(i, links)
links
# Out:
# BRA done!
# USA done!
# ROU done!
# RUS done!
# MEX done!
# JPN done!
# PHL done!
# AUS done!
# DZA done!
# COL done!
# THA done!
# TUR done!
# NGA done!
# VNM done!
# IND done!
# UKR done!
# HRV done!
# ARG done!
# NLD done!
# IDN done!
# NOR done!
# DEU done!
# POL done!
# GTM done!
# CHN done!
# VEN done!
# LKA done!
# EGY done!
# KEN done!
# YEM done!
# HND done!
# AFG done!
# CAN done!
# SWE done!
# PRT done!
# MNG done!
# SLV done!
# BGR done!
# MWI done!
# IRN done!
# KOR done!
# EST done!
# PRY done!
# BTN done!
# TUN done!
# URY done!
# ECU done!
# PER done!
# SVN done!
# GBR done!
# PRK done!
# TZA done!
# SLB done!
# KHM done!
# KAZ done!
# CHE done!
# CUB done!
# HUN done!
# AGO done!
# UGA done!
# SRB done!
# UZB done!
# DOM done!
# MYS done!
# LAO done!
# NIC done!
# GHA done!
# BDI done!
# MOZ done!
# BLR done!
# GUY done!
# ITA done!
# NAM done!
# DNK done!
# CZE done!
# AUT done!
# FRA done!
# IRQ done!
# BOL done!
# PNG done!
# MKD done!
# CRI done!
# SDN done!
# AZE done!
# ETH done!
# PAN done!
# SVK done!
# PRI done!
# BEN done!
# NZL done!
# SOM done!
# ZMB done!
# GEO done!
# LBR done!
# BGD done!
# MMR done!
# VUT done!
# SUR done!
# TLS done!
# ZWE done!
# TJK done!
# CMR done!
# SYR done!
# SWZ done!
# MAR done!
# TCD done!
# ESP done!
# ZAF done!
# CAF done!
# CHL done!
# ERI done!
# COG done!
# LTU done!
# OMN done!
# MLI done!
# BFA done!
# SEN done!
# SSD done!
# KGZ done!
# HTI done!
# COD done!
# ALB done!
# GAB done!
# GMB done!
# GNB done!
# JOR done!
# MDA done!
# NER done!
# GIN done!
# NCL done!
# CIV done!
# MRT done!
# BHS done!
# BRN done!
# GLP done!
# MTQ done!
# PAK done!
# GNQ done!
# LBN done!
# RWA done!
# XKO done!
# BWA done!
# IRL done!
# LVA done!
# IMN done!
# REU done!
# MDG done!
# TWN done!
# CPV done!
# FIN done!
# GUF done!
# LBY done!
# MNE done!
# TGO done!
# VIR done!
# BIH done!
# HKG done!
# MYT done!
# ALA done!
# PSE done!
# GGY done!
# TTO done!
# FJI done!
# GRC done!
# JAM done!
# KNA done!
# NPL done!
# SLE done!
# PLW done!
# BEL done!
# JEY done!
# LUX done!
# SAU done!
# ARM done!
# BMU done!
# BRB done!
# LIE done!
# DJI done!
# DMA done!
# LCA done!
# LSO done!
# MUS done!
# SMR done!
# ARE done!
# ATG done!
# MAC done!
# AND done!
# CYM done!
# GRD done!
# ISR done!
# STP done!
# BLZ done!
# KWT done!
# TCA done!
# TKM done!
# VCT done!
# CYP done!
# SGP done!
# VGB done!
# XNC done!
# BHR done!
# QAT done!
# BES done!
# COM done!
# MSR done!
# ESH done!
# SPM done!
# XAD done!
# ABW done!
# AIA done!
# ATF done!
# BLM done!
# CUW done!
# FLK done!
# FSM done!
# GIB done!
# GRL done!
# MAF done!
# MCO done!
# MDV done!
# MLT done!
# SXM done!
# SYC done!
# UMI done!
# VAT done!
# XCA done!
# CPU times: user 1.31 s, sys: 644 ms, total: 1.95 s
# Wall time: 2min 32s

# %%
len(links)
# Out:
# 226

# %%
links
# Out:
# [{'iso': 'BRA',
#   'links': '[{  "title": "Forest Products Legality Risk: Brazil Overview",  "url": "http://risk.forestlegality.org/countries/brazil"}, {  "title": "Imazon",  "url": "http://www.imazon.org.br"}, {  "title": "InfoAmazonia",  "url": "http://infoamazonia.org"}]'},
#  {'iso': 'USA', 'links': ''},
#  {'iso': 'ROU', 'links': ''},
#  {'iso': 'RUS', 'links': ''},
#  {'iso': 'MEX', 'links': ''},
#  {'iso': 'JPN', 'links': ''},
#  {'iso': 'PHL', 'links': ''},
#  {'iso': 'AUS', 'links': ''},
#  {'iso': 'DZA', 'links': ''},
#  {'iso': 'COL',
#   'links': '[{  "title": "InfoAmazonia",  "url": "http://infoamazonia.org"}]'},
#  {'iso': 'THA', 'links': ''},
#  {'iso': 'TUR', 'links': ''},
#  {'iso': 'NGA', 'links': ''},
#  {'iso': 'VNM',
#   'links': '[{  "title": "Forest Products Legality Risk: Vietnam Overview",  "url": "http://risk.forestlegality.org/countries/vietnam"}]'},
#  {'iso': 'IND', 'links': ''},
#  {'iso': 'UKR', 'links': ''},
#  {'iso': 'HRV', 'links': ''},
#  {'iso': 'ARG', 'links': ''},
#  {'iso': 'NLD', 'links': ''},
#  {'iso': 'IDN',
#   'links': '[{"title":"CIFOR (Center for International Forestry Research)","url":"http://www.cifor.org/"},{"title":"Eyes on the Forest","url":"http://maps.eyesontheforest.or.id/"},{"title":"Forest Products Legality Risk: Indonesia Overview","url":" ttp://risk.forestlegality.org/countries/indonesia "},{"title":"POTICO Forest Cover Analyzer","url":"http://www.wri.org/project/potico/about-forest-cover-analyzer"},{"title":"POTICO Suitability Mapper","url":"http://www.wri.org/project/potico/about-suitability-mapper"},{"title":"Project POTICO: Sustainable Palm Oil on Low Carbon Degraded Land","url":"http://www.wri.org/project/potico"},{"title":"REDD+ Task Force","url":"http://theredddesk.org/countries/actors/redd-taskforce-indonesia"}]'},
#  {'iso': 'NOR', 'links': ''},
#  {'iso': 'DEU', 'links': ''},
#  {'iso': 'POL', 'links': ''},
#  {'iso': 'GTM', 'links': ''},
#  {'iso': 'CHN',
#   'links': '[{  "title": "Forest Products Legality Risk: China Overview",  "url": "http://risk.forestlegality.org/countries/china"}]'},
#  {'iso': 'VEN',
#   'links': '[{  "title": "InfoAmazonia",  "url": "http://infoamazonia.org"}]'},
#  {'iso': 'LKA', 'links': ''},
#  {'iso': 'EGY', 'links': ''},
#  {'iso': 'KEN', 'links': ''},
#  {'iso': 'YEM', 'links': ''},
#  {'iso': 'HND',
#   'links': '[{  "title": "Forest Products Legality Risk: Honduras Overview",  "url": "http://risk.forestlegality.org/countries/honduras"}]'},
#  {'iso': 'AFG', 'links': ''},
#  {'iso': 'CAN', 'links': ''},
#  {'iso': 'SWE', 'links': ''},
#  {'iso': 'PRT', 'links': ''},
#  {'iso': 'MNG', 'links': ''},
#  {'iso': 'SLV', 'links': ''},
#  {'iso': 'BGR', 'links': ''},
#  {'iso': 'MWI', 'links': ''},
#  {'iso': 'IRN', 'links': ''},
#  {'iso': 'KOR', 'links': ''},
#  {'iso': 'EST', 'links': ''},
#  {'iso': 'PRY', 'links': ''},
#  {'iso': 'BTN', 'links': ''},
#  {'iso': 'TUN', 'links': ''},
#  {'iso': 'URY', 'links': ''},
#  {'iso': 'ECU',
#   'links': '[{  "title": "InfoAmazonia",  "url": "http://infoamazonia.org"}]'},
#  {'iso': 'PER',
#   'links': '[{  "title": "Forest Products Legality Risk: Peru Overview",  "url": "http://risk.forestlegality.org/countries/peru"}, {  "title": "InfoAmazonia",  "url": "http://infoamazonia.org"}]'},
#  {'iso': 'SVN', 'links': ''},
#  {'iso': 'GBR', 'links': ''},
#  {'iso': 'PRK', 'links': ''},
#  {'iso': 'TZA',
#   'links': '[{  "title": "Tanzania\'s 2002 Forest Act",  "url": "http://www.tanzania.go.tz/egov_uploads/documents/The_Forest_Act,_14-2002_en.pdf"}]'},
#  {'iso': 'SLB', 'links': ''},
#  {'iso': 'KHM', 'links': ''},
#  {'iso': 'KAZ', 'links': ''},
#  {'iso': 'CHE', 'links': ''},
#  {'iso': 'CUB', 'links': ''},
#  {'iso': 'HUN', 'links': ''},
#  {'iso': 'AGO', 'links': ''},
#  {'iso': 'UGA', 'links': ''},
#  {'iso': 'SRB', 'links': ''},
#  {'iso': 'UZB', 'links': ''},
#  {'iso': 'DOM', 'links': ''},
#  {'iso': 'MYS',
#   'links': '[{  "title": "Forest Products Legality Risk: Malaysia Overview",  "url": "http://risk.forestlegality.org/countries/malaysia"}]'},
#  {'iso': 'LAO', 'links': ''},
#  {'iso': 'NIC', 'links': ''},
#  {'iso': 'GHA', 'links': ''},
#  {'iso': 'BDI', 'links': ''},
#  {'iso': 'MOZ', 'links': ''},
#  {'iso': 'BLR', 'links': ''},
#  {'iso': 'GUY',
#   'links': '[{  "title": "InfoAmazonia",  "url": "http://infoamazonia.org"}]'},
#  {'iso': 'ITA', 'links': ''},
#  {'iso': 'NAM', 'links': ''},
#  {'iso': 'DNK', 'links': ''},
#  {'iso': 'CZE', 'links': ''},
#  {'iso': 'AUT', 'links': ''},
#  {'iso': 'FRA', 'links': ''},
#  {'iso': 'IRQ', 'links': ''},
#  {'iso': 'BOL',
#   'links': '[{  "title": "InfoAmazonia",  "url": "http://infoamazonia.org"}]'},
#  {'iso': 'PNG',
#   'links': '[{  "title": "Forest Products Legality Risk: Papua New Guinea Overview",  "url": "http://risk.forestlegality.org/countries/papua-new-guinea"}]'},
#  {'iso': 'MKD', 'links': ''},
#  {'iso': 'CRI', 'links': ''},
#  {'iso': 'SDN', 'links': ''},
#  {'iso': 'AZE', 'links': ''},
#  {'iso': 'ETH', 'links': ''},
#  {'iso': 'PAN', 'links': ''},
#  {'iso': 'SVK', 'links': ''},
#  {'iso': 'PRI', 'links': ''},
#  {'iso': 'BEN', 'links': ''},
#  {'iso': 'NZL', 'links': ''},
#  {'iso': 'SOM', 'links': ''},
#  {'iso': 'ZMB', 'links': ''},
#  {'iso': 'GEO', 'links': ''},
#  {'iso': 'LBR', 'links': ''},
#  {'iso': 'BGD', 'links': ''},
#  {'iso': 'MMR', 'links': ''},
#  {'iso': 'VUT', 'links': ''},
#  {'iso': 'SUR',
#   'links': '[{  "title": "InfoAmazonia",  "url": "http://infoamazonia.org"}]'},
#  {'iso': 'TLS', 'links': ''},
#  {'iso': 'ZWE', 'links': ''},
#  {'iso': 'TJK', 'links': ''},
#  {'iso': 'CMR',
#   'links': '[{  "title": "Interactive Forest Atlas of Cameroon",  "url": "http://www.wri.org/project/interactive-forest-atlas-cameroon"}]'},
#  {'iso': 'SYR', 'links': ''},
#  {'iso': 'SWZ', 'links': ''},
#  {'iso': 'MAR', 'links': ''},
#  {'iso': 'TCD', 'links': ''},
#  {'iso': 'ESP', 'links': ''},
#  {'iso': 'ZAF', 'links': ''},
#  {'iso': 'CAF',
#   'links': '[{  "title": "Forest Atlas of Central African Republic",  "url": "http://www.wri.org/project/interactive-forest-atlas-central-african-republic"}]'},
#  {'iso': 'CHL', 'links': ''},
#  {'iso': 'ERI', 'links': ''},
#  {'iso': 'COG',
#   'links': '[{  "title": "Interactive Forest Atlas of Congo",  "url": "http://www.wri.org/project/interactive-forest-atlas-congo"}, {  "title": "OSFAC",  "url": "http://osfac.net/index.php?lang=en"}]'},
#  {'iso': 'LTU', 'links': ''},
#  {'iso': 'OMN', 'links': ''},
#  {'iso': 'MLI', 'links': ''},
#  {'iso': 'BFA', 'links': ''},
#  {'iso': 'SEN', 'links': ''},
#  {'iso': 'SSD', 'links': ''},
#  {'iso': 'KGZ', 'links': ''},
#  {'iso': 'HTI', 'links': ''},
#  {'iso': 'COD',
#   'links': '[{  "title": "DRC Mining",  "url": "http://www.drcmining.org/fr"}, {  "title": "Interactive Forest Atlas for Democratic Republic of Congo",  "url": "http://www.wri.org/project/interactive-forest-atlas-democratic-republic-of-congo"}, {  "title": "Moabi",  "url": "http://drc.moabi.org/"}, {  "title": "National Forest Monitoring System: DRC",  "url": "http://www.rdc-snsf.org/"}, {  "title": "OSFAC",  "url": "http://osfac.net/index.php?lang=en"}]'},
#  {'iso': 'ALB', 'links': ''},
#  {'iso': 'GAB',
#   'links': '[{  "title": "Forest Products Legality Risk: Gabon Overview",  "url": "http://risk.forestlegality.org/countries/gabon"}, {  "title": "Gabon Spatial Agency",  "url": "http://www.ageos.ga/web/guest"}, {  "title": "Interactive Forest Atlas for Gabon",  "url": "http://www.wri.org/publication/interactive-forestry-atlas-gabon"}]'},
#  {'iso': 'GMB', 'links': ''},
#  {'iso': 'GNB', 'links': ''},
#  {'iso': 'JOR', 'links': ''},
#  {'iso': 'MDA', 'links': ''},
#  {'iso': 'NER', 'links': ''},
#  {'iso': 'GIN', 'links': ''},
#  {'iso': 'NCL', 'links': ''},
#  {'iso': 'CIV', 'links': ''},
#  {'iso': 'MRT', 'links': ''},
#  {'iso': 'BHS', 'links': ''},
#  {'iso': 'BRN', 'links': ''},
#  {'iso': 'GLP', 'links': None},
#  {'iso': 'MTQ', 'links': ''},
#  {'iso': 'PAK', 'links': ''},
#  {'iso': 'GNQ', 'links': ''},
#  {'iso': 'LBN', 'links': ''},
#  {'iso': 'RWA', 'links': ''},
#  {'iso': 'XKO', 'links': None},
#  {'iso': 'BWA', 'links': ''},
#  {'iso': 'IRL', 'links': ''},
#  {'iso': 'LVA', 'links': ''},
#  {'iso': 'IMN', 'links': ''},
#  {'iso': 'REU', 'links': ''},
#  {'iso': 'MDG', 'links': ''},
#  {'iso': 'TWN', 'links': ''},
#  {'iso': 'CPV', 'links': ''},
#  {'iso': 'FIN', 'links': ''},
#  {'iso': 'GUF', 'links': ''},
#  {'iso': 'LBY', 'links': ''},
#  {'iso': 'MNE', 'links': ''},
#  {'iso': 'TGO', 'links': ''},
#  {'iso': 'VIR', 'links': None},
#  {'iso': 'BIH', 'links': ''},
#  {'iso': 'HKG', 'links': ''},
#  {'iso': 'MYT', 'links': None},
#  {'iso': 'ALA', 'links': None},
#  {'iso': 'PSE', 'links': None},
#  {'iso': 'GGY', 'links': ''},
#  {'iso': 'TTO', 'links': ''},
#  {'iso': 'FJI', 'links': ''},
#  {'iso': 'GRC', 'links': ''},
#  {'iso': 'JAM', 'links': ''},
#  {'iso': 'KNA', 'links': None},
#  {'iso': 'NPL', 'links': ''},
#  {'iso': 'SLE', 'links': ''},
#  {'iso': 'PLW', 'links': ''},
#  {'iso': 'BEL', 'links': ''},
#  {'iso': 'JEY', 'links': ''},
#  {'iso': 'LUX', 'links': ''},
#  {'iso': 'SAU', 'links': ''},
#  {'iso': 'ARM', 'links': ''},
#  {'iso': 'BMU', 'links': ''},
#  {'iso': 'BRB', 'links': ''},
#  {'iso': 'LIE', 'links': ''},
#  {'iso': 'DJI', 'links': None},
#  {'iso': 'DMA', 'links': ''},
#  {'iso': 'LCA', 'links': ''},
#  {'iso': 'LSO', 'links': ''},
#  {'iso': 'MUS', 'links': ''},
#  {'iso': 'SMR', 'links': ''},
#  {'iso': 'ARE', 'links': ''},
#  {'iso': 'ATG', 'links': ''},
#  {'iso': 'MAC', 'links': ''},
#  {'iso': 'AND', 'links': ''},
#  {'iso': 'CYM', 'links': ''},
#  {'iso': 'GRD', 'links': ''},
#  {'iso': 'ISR', 'links': ''},
#  {'iso': 'STP', 'links': ''},
#  {'iso': 'BLZ', 'links': ''},
#  {'iso': 'KWT', 'links': None},
#  {'iso': 'TCA', 'links': None},
#  {'iso': 'TKM', 'links': ''},
#  {'iso': 'VCT', 'links': ''},
#  {'iso': 'CYP', 'links': ''},
#  {'iso': 'SGP', 'links': ''},
#  {'iso': 'VGB', 'links': None},
#  {'iso': 'XNC', 'links': None},
#  {'iso': 'BHR', 'links': None},
#  {'iso': 'QAT', 'links': None},
#  {'iso': 'BES', 'links': None},
#  {'iso': 'COM', 'links': ''},
#  {'iso': 'MSR', 'links': ''},
#  {'iso': 'ESH', 'links': None},
#  {'iso': 'SPM', 'links': ''},
#  {'iso': 'XAD', 'links': None},
#  {'iso': 'ABW', 'links': ''},
#  {'iso': 'AIA', 'links': ''},
#  {'iso': 'ATF', 'links': None},
#  {'iso': 'BLM', 'links': ''},
#  {'iso': 'CUW', 'links': ''},
#  {'iso': 'FLK', 'links': None},
#  {'iso': 'FSM', 'links': ''},
#  {'iso': 'GIB', 'links': None},
#  {'iso': 'GRL', 'links': None},
#  {'iso': 'MAF', 'links': ''},
#  {'iso': 'MCO', 'links': None},
#  {'iso': 'MDV', 'links': ''},
#  {'iso': 'MLT', 'links': ''},
#  {'iso': 'SXM', 'links': ''},
#  {'iso': 'SYC', 'links': ''},
#  {'iso': 'UMI', 'links': None},
#  {'iso': 'VAT', 'links': None},
#  {'iso': 'XCA', 'links': None}]

# %%
# Create lists for iso, external links, and a forest atlas
# If forest atlas is present in the link then return True

fa = []
ext_links = []
country = []

for l in links:
    link_string = l.get('links')
    
    if link_string and 'Atlas' in link_string:
        fa.append(True)
        ext_links.append(l.get('links'))
        country.append(l.get('iso'))
        
    else:
        fa.append(False)
        ext_links.append(l.get('links'))
        country.append(l.get('iso'))

# %%
# Create dataframe

tmp_data = []
for n in range(len(country)):
    tmp_data.append([country[n], fa[n], ext_links[n]])

# %%
cnames=['iso', 'forest_atlas', 'external_links']

df = pd.DataFrame(tmp_data, columns=cnames)

# %%
df.head()
# Out:
#    iso  forest_atlas                                     external_links
# 0  BRA         False  [{  "title": "Forest Products Legality Risk: B...
# 1  USA         False
# 2  ROU         False
# 3  RUS         False
# 4  MEX         False

# %%
# Craete csv
file_name = 'data_sci_tutorials/scraped_links.csv'

df.to_csv(file_name, encoding='utf-8', index=False)
